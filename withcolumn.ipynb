# %%
data = [('James','','Smith','1991-04-01','M',3000),
  ('Michael','Rose','','2000-05-19','M',4000),
  ('Robert','','Williams','1978-09-05','M',4000),
  ('Maria','Anne','Jones','1967-12-01','F',4000),
  ('Jen','Mary','Brown','1980-02-17','F',-1)
]

columns = ["firstname","middlename","lastname","dob","gender","salary"]

df = spark.createDataFrame(data,columns)
df.show()
# Out:
# +---------+----------+--------+----------+------+------+
# |firstname|middlename|lastname|       dob|gender|salary|
# +---------+----------+--------+----------+------+------+
# |    James|          |   Smith|1991-04-01|     M|  3000|
# |  Michael|      Rose|        |2000-05-19|     M|  4000|
# |   Robert|          |Williams|1978-09-05|     M|  4000|
# |    Maria|      Anne|   Jones|1967-12-01|     F|  4000|
# |      Jen|      Mary|   Brown|1980-02-17|     F|    -1|
# +---------+----------+--------+----------+------+------+

# %%
df.withColumn("salary",df["salary"].cast('Integer')).printSchema()
df.withColumn("salary",df["salary"].cast('Integer')).show()
# Out:
# root
#  |-- firstname: string (nullable = true)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = true)
#  |-- dob: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#
# +---------+----------+--------+----------+------+------+
# |firstname|middlename|lastname|       dob|gender|salary|
# +---------+----------+--------+----------+------+------+
# |    James|          |   Smith|1991-04-01|     M|  3000|
# |  Michael|      Rose|        |2000-05-19|     M|  4000|
# |   Robert|          |Williams|1978-09-05|     M|  4000|
# |    Maria|      Anne|   Jones|1967-12-01|     F|  4000|
# |      Jen|      Mary|   Brown|1980-02-17|     F|    -1|
# +---------+----------+--------+----------+------+------+

# %%
df.withColumn("Salary",df["salary"] * 10).show()
# Out:
# +---------+----------+--------+----------+------+------+
# |firstname|middlename|lastname|       dob|gender|Salary|
# +---------+----------+--------+----------+------+------+
# |    James|          |   Smith|1991-04-01|     M| 30000|
# |  Michael|      Rose|        |2000-05-19|     M| 40000|
# |   Robert|          |Williams|1978-09-05|     M| 40000|
# |    Maria|      Anne|   Jones|1967-12-01|     F| 40000|
# |      Jen|      Mary|   Brown|1980-02-17|     F|   -10|
# +---------+----------+--------+----------+------+------+

# %%
df.withColumn("Country",lit('IND')).show()
# Out:
# +---------+----------+--------+----------+------+------+-------+
# |firstname|middlename|lastname|       dob|gender|salary|Country|
# +---------+----------+--------+----------+------+------+-------+
# |    James|          |   Smith|1991-04-01|     M|  3000|    IND|
# |  Michael|      Rose|        |2000-05-19|     M|  4000|    IND|
# |   Robert|          |Williams|1978-09-05|     M|  4000|    IND|
# |    Maria|      Anne|   Jones|1967-12-01|     F|  4000|    IND|
# |      Jen|      Mary|   Brown|1980-02-17|     F|    -1|    IND|
# +---------+----------+--------+----------+------+------+-------+

# %%
df.withColumnRenamed("gender","Sex").show()
# Out:
# +---------+----------+--------+----------+---+------+
# |firstname|middlename|lastname|       dob|Sex|salary|
# +---------+----------+--------+----------+---+------+
# |    James|          |   Smith|1991-04-01|  M|  3000|
# |  Michael|      Rose|        |2000-05-19|  M|  4000|
# |   Robert|          |Williams|1978-09-05|  M|  4000|
# |    Maria|      Anne|   Jones|1967-12-01|  F|  4000|
# |      Jen|      Mary|   Brown|1980-02-17|  F|    -1|
# +---------+----------+--------+----------+---+------+
